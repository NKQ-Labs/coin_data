# %%
import os
import pandas as pd
import datetime as dt

# %%
os.path.isdir( os.path.join(os.getcwd(), '/tempDir'))


os.mkdir('binance_1min')
os.mkdir('upbit_1min')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-2-8c489bde3d09> in <module>
#       2
#       3
# ----> 4 os.mkdir('binance_1min')
#       5 os.mkdir('upbit_1min')
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'binance_1min'

# %% [markdown]
# GoPax folder

# %%
gopax_base_path=os.path.join(os.getcwd(), 'GoPax_5min')

# %%
# print(gopax_base_path)

print(os.getcwd())
# Out:
# C:\Users\MonKey-K\coin_data

# %%
os.path.isdir(gopax_base_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1ed976011f8> in <module>
# ----> 1 os.path.isdir(gopax_base_path)
#       2
#
# NameError: name 'gopax_base_path' is not defined

# %%
os.path.join(os.getcwd(), 'new_folder')
# Out:
# 'C:\\Users\\NK\\coin_data\\new_folder'

# %%
# dirName = 'tempDir2/temp2/temp'

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2020,1,1), end = dt.datetime.now(), freq='M'))

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00]

# %%
month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y%m'))

# %%
month_list=month_list.tolist()

# %%
month_list
# Out:
# ['202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105']

# %%
pd.Series()
# Out:
# <ipython-input-7-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
month_list=month_list.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-949532d1abda> in <module>
# ----> 1 month_list=month_list.tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
for time in month_list:
    print(os.path.join(gopax_base_path,time) )
    if os.path.isdir ( os.path.join(gopax_base_path,time) ) is False:
        os.mkdir(os.path.join(gopax_base_path,time) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a300ec0882c3> in <module>
#       1 for time in month_list:
# ----> 2     print(os.path.join(gopax_base_path,time) )
#       3     if os.path.isdir ( os.path.join(gopax_base_path,time) ) is False:
#       4         os.mkdir(os.path.join(gopax_base_path,time) )
#
# NameError: name 'gopax_base_path' is not defined

# %%
binance_base_path=os.path.join(os.getcwd(), 'binance_1min')
upbit_base_path=os.path.join(os.getcwd(), 'upbit_1min')

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2015,1,1), end = dt.datetime.now(), freq='M'))

month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y%m'))

# %%
month_list=month_list.to_list()
print(month_list)
# Out:
# ['201501', '201502', '201503', '201504', '201505', '201506', '201507', '201508', '201509', '201510', '201511', '201512', '201601', '201602', '201603', '201604', '201605', '201606', '201607', '201608', '201609', '201610', '201611', '201612', '201701', '201702', '201703', '201704', '201705', '201706', '201707', '201708', '201709', '201710', '201711', '201712', '201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810', '201811', '201812', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010', '202011', '202012', '202101', '202102', '202103', '202104', '202105']

# %%
for time in month_list:
    print(os.path.join(upbit_base_path,time) )
    if os.path.isdir ( os.path.join(upbit_base_path,time) ) is False:
        os.mkdir(os.path.join(upbit_base_path,time) )







# for time in month_list:
#     print(os.path.join(binance_base_path,time) )
#     if os.path.isdir ( os.path.join(binance_base_path,time) ) is False:
#         os.mkdir(      os.path.join(binance_base_path,time) )
# Out:
# C:\Users\MonKey-K\coin_data\upbit_1min\201501
# C:\Users\MonKey-K\coin_data\upbit_1min\201502
# C:\Users\MonKey-K\coin_data\upbit_1min\201503
# C:\Users\MonKey-K\coin_data\upbit_1min\201504
# C:\Users\MonKey-K\coin_data\upbit_1min\201505
# C:\Users\MonKey-K\coin_data\upbit_1min\201506
# C:\Users\MonKey-K\coin_data\upbit_1min\201507
# C:\Users\MonKey-K\coin_data\upbit_1min\201508
# C:\Users\MonKey-K\coin_data\upbit_1min\201509
# C:\Users\MonKey-K\coin_data\upbit_1min\201510
# C:\Users\MonKey-K\coin_data\upbit_1min\201511
# C:\Users\MonKey-K\coin_data\upbit_1min\201512
# C:\Users\MonKey-K\coin_data\upbit_1min\201601
# C:\Users\MonKey-K\coin_data\upbit_1min\201602
# C:\Users\MonKey-K\coin_data\upbit_1min\201603
# C:\Users\MonKey-K\coin_data\upbit_1min\201604
# C:\Users\MonKey-K\coin_data\upbit_1min\201605
# C:\Users\MonKey-K\coin_data\upbit_1min\201606
# C:\Users\MonKey-K\coin_data\upbit_1min\201607
# C:\Users\MonKey-K\coin_data\upbit_1min\201608
# ...
