# %% [markdown]
# # GoPax 5 min data OHCLV

# %%
# !pip install ccxt

# %%
import pandas as pd
import os
import datetime as dt
import numpy as np
#!/usr/bin/python
import ccxt
import calendar
from datetime import datetime, date, timedelta

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2020,1,1), end = dt.datetime.now(), freq='M'))
month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y%m'))

# %%
import pandas as pd
import os
import datetime as dt
import numpy as np
#!/usr/bin/python
import ccxt
import calendar
from datetime import datetime, date, timedelta

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2020,1,1), \
                        end= dt.datetime.now(), freq='M'))
month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y%m'))

# %%
print(month_list)
# Out:
# 2020-01-31    202001
# 2020-02-29    202002
# 2020-03-31    202003
# 2020-04-30    202004
# 2020-05-31    202005
# 2020-06-30    202006
# 2020-07-31    202007
# 2020-08-31    202008
# 2020-09-30    202009
# 2020-10-31    202010
# 2020-11-30    202011
# 2020-12-31    202012
# 2021-01-31    202101
# 2021-02-28    202102
# 2021-03-31    202103
# 2021-04-30    202104
# 2021-05-31    202105
# Freq: M, dtype: object

# %%
month_list.tolist()
# Out:
# ['202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105']

# %%
from datetime import date, timedelta, datetime

def days_cur_month(input_month_list):
    
    res={}
    for input_month in input_month_list:
        year=int(input_month[0:4])
        month=input_month[-2:]
        month=int(month)
        
#         print(input_month)
        m = month
#         print(month)
        y=year
#         y = datetime.now().year
        if m<12:
            ndays = (date(y, m+1, 1) - date(y, m, 1)).days
        else:
            ndays=(date(y+1, 1, 1) - date(y, m, 1)).days
        d1 = date(y, m, 1)
        d2 = date(y, m, ndays)
        delta = d2 - d1
        res[input_month]=[   (d1 + timedelta(days=i)).strftime('%Y%m%d') for i in range(delta.days + 1)] 


        
    return res

#days_cur_month()#

# %%
dictionary_month=days_cur_month(month_list.tolist())

# %%
for month in dictionary_month:
    print(month)
    print(dictionary_month[month])
# Out:
# 202001
# ['20200101', '20200102', '20200103', '20200104', '20200105', '20200106', '20200107', '20200108', '20200109', '20200110', '20200111', '20200112', '20200113', '20200114', '20200115', '20200116', '20200117', '20200118', '20200119', '20200120', '20200121', '20200122', '20200123', '20200124', '20200125', '20200126', '20200127', '20200128', '20200129', '20200130', '20200131']
# 202002
# ['20200201', '20200202', '20200203', '20200204', '20200205', '20200206', '20200207', '20200208', '20200209', '20200210', '20200211', '20200212', '20200213', '20200214', '20200215', '20200216', '20200217', '20200218', '20200219', '20200220', '20200221', '20200222', '20200223', '20200224', '20200225', '20200226', '20200227', '20200228', '20200229']
# 202003
# ['EOS_USDT', 'XRP_USDT', 'BTC_USDT', 'ETH_USDT', 'DOGE_USDT', 'ZEC_USDT', 'BCH_USDT', 'ADA_USDT', 'XLM_USDT', 'LINK_USDT', 'LTC_USDT', 'ALGO_USDT', 'ATOM_USDT']

# %%
# funded='./binance_1min'
# month='202001'
# path=os.path.join(os.getcwd(),'binance_1min',  month)
# path=os.path.join(path , "BTC_USDT.csv" )

# print(path)

# # print(path)
# df.to_csv(path, header=True, index=True)

# %%
 df = ohlcv(A, "BTC/USDT", '1m')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-59ba6e41ef22> in <module>
# ----> 1 df = ohlcv(A, "BTC/USDT", '1m')
#
# NameError: name 'ohlcv' is not defined

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00, 2021-05-31 00:00:00]

# %%
for coin in binance_coin_list:
    df = ohlcv(dt, coin, '1m')
    print(df)
    df.to_csv("temp.csv", header=True, index=True)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-707a37044fa0> in <module>
#       1 for coin in binance_coin_list:
# ----> 2     df = ohlcv(dt, coin, '1m')
#       3     print(df)
#       4     df.to_csv("temp.csv", header=True, index=True)
#       5     break
#
# NameError: name 'ohlcv' is not defined

# %%
print(coin_list[4][:-4])
print(coin_list[4][-4:])
# Out:
# DODGE
# /KRW

# %%
bull_coin_list
# Out:
# ['EOSBULL/KRW',
#  'XRPBULL/KRW',
#  'BTCBULL/KRW',
#  'ETHBULL/KRW',
#  'DODGEBULL/KRW',
#  'ZECBULL/KRW',
#  'BCHBULL/KRW',
#  'ADABULL/KRW',
#  'XLMBULL/KRW',
#  'LINKBULL/KRW',
#  'LTCBULL/KRW',
#  'ALGOBULL/KRW',
#  'ATOMBULL/KRW']

# %%
#!/usr/bin/python
import ccxt
import calendar
from datetime import datetime, date, timedelta

upbit = ccxt.upbit()

def min_ohlcv(dt, pair, limit):
    # UTC native object
    since = calendar.timegm(dt.utctimetuple())*1000
    ohlcv1 = upbit.fetch_ohlcv(symbol=pair, timeframe='1m', since=since, limit=limit)
    ohlcv2 = upbit.fetch_ohlcv(symbol=pair, timeframe='1m', since=since+60*6*12*10000, limit=limit)
    ohlcv = ohlcv1 + ohlcv2
    return ohlcv

def ohlcv(dt, pair, period='1d'):
    ohlcv = []
    limit = 1000
    if period == '1m':
        limit = 720
    elif period == '1d':
        limit = 365
    elif period == '1h':
        limit = 24
    elif period == '5m':
        limit = 288
    for i in dt:
        start_dt = datetime.strptime(i, "%Y%m%d")
        since = calendar.timegm(start_dt.utctimetuple())*1000
        if period == '1m':
            ohlcv.extend(min_ohlcv(start_dt, pair, limit))
        else:
            ohlcv.extend(upbit.fetch_ohlcv(symbol=pair, timeframe=period, since=since, limit=limit))
    df = pd.DataFrame(ohlcv, columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume'])
    df['Time'] = [datetime.fromtimestamp(float(time)/1000) for time in df['Time']]
    df['Open'] = df['Open'].astype(np.float64)
    df['High'] = df['High'].astype(np.float64)
    df['Low'] = df['Low'].astype(np.float64)
    df['Close'] = df['Close'].astype(np.float64)
    df['Volume'] = df['Volume'].astype(np.float64)
    df.set_index('Time', inplace=True)
    return df

dt = ['20190101', '20200101']
df = ohlcv(dt, 'ETH/BTC', '1h')

# %%
for month in dictionary_month: 
    for coin in upbit_coin_list:
        path=os.path.join(os.getcwd(),'upbit_1min',  month)
        data_name=   coin[:-4] +'_'+coin[-3:]+".csv"
        path=os.path.join(path , data_name )

        print(path)
        print(coin)
        if coin not in upbit.symbols:
            continue
        df=ohlcv(dictionary_month[month], coin, '1m')
        df.to_csv(path, header=True, index=True)
# Out:
# C:\Users\NK\coin_data\upbit_1min\202001\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202001\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202002\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202003\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202004\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202005\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202006\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202007\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202008\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202009\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202010\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202011\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202012\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202101\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202102\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202103\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202104\ATOM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\EOS_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\XRP_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\BTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\ETH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\DOGE_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\ZEC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\BCH_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\ADA_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\XLM_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\LINK_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\LTC_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\ALGO_KRW.csv
# C:\Users\NK\coin_data\upbit_1min\202105\ATOM_KRW.csv

# %%
print("upbit_done!")
# Out:
# upbit_done!

# %%
# Out:
# ['ADA/BTC',
#  'ADA/KRW',
#  'ADA/USDT',
#  'ADX/BTC',
#  'ADX/KRW',
#  'AERGO/BTC',
#  'AERGO/KRW',
#  'AHT/BTC',
#  'AHT/KRW',
#  'ALGO/BTC',
#  'ANKR/BTC',
#  'ANKR/KRW',
#  'ANT/BTC',
#  'AQT/BTC',
#  'AQT/KRW',
#  'ARDR/BTC',
#  'ARDR/KRW',
#  'ARK/BTC',
#  'ARK/KRW',
#  'ATOM/BTC',
#  'ATOM/KRW',
#  'AUCTION/BTC',
#  'AXS/BTC',
#  'AXS/KRW',
#  'BASIC/BTC',
#  'BAT/BTC',
#  'BAT/KRW',
#  'BAT/USDT',
#  'BCH/BTC',
#  'BCH/KRW',
#  'BCH/USDT',
#  'BCHA/BTC',
#  'BCHA/KRW',
#  'BFC/BTC',
#  'BFT/BTC',
#  'BNT/BTC',
#  'BORA/BTC',
#  'BORA/KRW',
#  'BSV/BTC',
#  'BSV/KRW',
#  'BTC/KRW',
#  'BTC/USDT',
#  'BTG/KRW',
#  'BTT/BTC',
#  'BTT/KRW',
#  'CBK/BTC',
#  'CBK/KRW',
#  'CELO/BTC',
#  'CHR/BTC',
#  'CHZ/BTC',
#  'CHZ/KRW',
#  'COMP/BTC',
#  'CRE/KRW',
#  'CRO/BTC',
#  'CRO/KRW',
#  'CRV/BTC',
#  'CTSI/BTC',
#  'CVC/BTC',
#  'CVC/KRW',
#  'DAD/BTC',
#  'DAI/BTC',
#  'DAWN/BTC',
#  'DAWN/KRW',
#  'DENT/BTC',
#  'DGB/BTC',
#  'DGB/USDT',
#  'DKA/BTC',
#  'DKA/KRW',
#  'DMT/BTC',
#  'DMT/KRW',
#  'DNT/BTC',
#  'DOGE/BTC',
#  'DOGE/KRW',
#  'DOGE/USDT',
#  'DOT/BTC',
#  'DOT/KRW',
#  'EDR/BTC',
#  'EDR/KRW',
#  'ELF/BTC',
#  'ELF/KRW',
#  'EMC2/BTC',
#  'EMC2/KRW',
#  'ENJ/BTC',
#  'ENJ/KRW',
#  'EOS/BTC',
#  'EOS/KRW',
#  'ETC/BTC',
#  'ETC/KRW',
#  'ETC/USDT',
#  'ETH/BTC',
#  'ETH/KRW',
#  'ETH/USDT',
#  'FCT2/BTC',
#  'FCT2/KRW',
#  'FIL/BTC',
#  'FLOW/BTC',
#  'FLOW/KRW',
#  'FOR/BTC',
#  'FSN/BTC',
#  'FX/BTC',
#  'GAS/KRW',
#  'GLM/BTC',
#  'GLM/KRW',
#  'GO/BTC',
#  'GRS/BTC',
#  'GRS/KRW',
#  'GRT/BTC',
#  'GXC/BTC',
#  'HBAR/KRW',
#  'HBD/BTC',
#  'HIVE/BTC',
#  'HIVE/KRW',
#  'HUM/BTC',
#  'HUM/KRW',
#  'HUNT/BTC',
#  'HUNT/KRW',
#  'ICX/KRW',
#  'IGNIS/BTC',
#  'IGNIS/KRW',
#  'INJ/BTC',
#  'IOST/BTC',
#  'IOST/KRW',
#  'IOTA/KRW',
#  'IOTX/BTC',
#  'IQ/BTC',
#  'IQ/KRW',
#  'ITAM/BTC',
#  'JST/BTC',
#  'JST/KRW',
#  'JUV/BTC',
#  'KAVA/BTC',
#  'KAVA/KRW',
#  'KMD/BTC',
#  'KMD/KRW',
#  'KNC/KRW',
#  'LAMB/BTC',
#  'LAMB/KRW',
#  'LBC/BTC',
#  'LBC/KRW',
#  'LINA/BTC',
#  'LINK/BTC',
#  'LINK/KRW',
#  'LOOM/BTC',
#  'LOOM/KRW',
#  'LRC/BTC',
#  'LSK/BTC',
#  'LSK/KRW',
#  'LTC/BTC',
#  'LTC/KRW',
#  'LTC/USDT',
#  'LUNA/BTC',
#  'MANA/BTC',
#  'MANA/KRW',
#  'MARO/BTC',
#  'MARO/KRW',
#  'MBL/KRW',
#  'MED/BTC',
#  'MED/KRW',
#  'META/BTC',
#  'META/KRW',
#  'MFT/BTC',
#  'MFT/KRW',
#  'MKR/BTC',
#  'MLK/BTC',
#  'MLK/KRW',
#  'MOC/BTC',
#  'MOC/KRW',
#  'MTL/BTC',
#  'MTL/KRW',
#  'MVL/BTC',
#  'MVL/KRW',
#  'NCASH/BTC',
#  'NEAR/BTC',
#  'NEO/KRW',
#  'NKN/BTC',
#  'NMR/BTC',
#  'NXT/BTC',
#  'OBSR/BTC',
#  'OBSR/KRW',
#  'OGN/BTC',
#  'OMG/BTC',
#  'OMG/KRW',
#  'OMG/USDT',
#  'ONG/KRW',
#  'ONIT/BTC',
#  'ONT/KRW',
#  'ORBS/BTC',
#  'ORBS/KRW',
#  'OXT/BTC',
#  'PAX/BTC',
#  'PCI/BTC',
#  'PCI/KRW',
#  'PI/BTC',
#  'PICA/BTC',
#  'PLA/BTC',
#  'PLA/KRW',
#  'POLY/BTC',
#  'POLY/KRW',
#  'POWR/BTC',
#  'POWR/KRW',
#  'PRO/BTC',
#  'PROM/BTC',
#  'PSG/BTC',
#  'PUNDIX/BTC',
#  'PUNDIX/KRW',
#  'PXL/BTC',
#  'PXL/KRW',
#  'QKC/KRW',
#  'QTCON/BTC',
#  'QTCON/KRW',
#  'QTUM/BTC',
#  'QTUM/KRW',
#  'RCN/BTC',
#  'RDD/BTC',
#  'REP/BTC',
#  'REP/KRW',
#  'RFR/BTC',
#  'RFR/KRW',
#  'RINGX/BTC',
#  'RLC/BTC',
#  'RSR/BTC',
#  'RVN/BTC',
#  'RVN/USDT',
#  'SAND/BTC',
#  'SAND/KRW',
#  'SBD/BTC',
#  'SBD/KRW',
#  'SC/BTC',
#  'SC/KRW',
#  'SC/USDT',
#  'SNT/BTC',
#  'SNT/KRW',
#  'SNX/BTC',
#  'SOLVE/BTC',
#  'SOLVE/KRW',
#  'SRM/BTC',
#  'SRM/KRW',
#  'SSX/BTC',
#  'SSX/KRW',
#  'STEEM/BTC',
#  'STEEM/KRW',
#  'STMX/BTC',
#  'STMX/KRW',
#  'STORJ/BTC',
#  'STORJ/KRW',
#  'STPT/BTC',
#  'STPT/KRW',
#  'STRAX/BTC',
#  'STRAX/KRW',
#  'STRK/BTC',
#  'STRK/KRW',
#  'STX/BTC',
#  'STX/KRW',
#  'SUN/BTC',
#  'SXP/BTC',
#  'SXP/KRW',
#  'SYS/BTC',
#  'TFUEL/KRW',
#  'THETA/KRW',
#  'TRX/BTC',
#  'TRX/KRW',
#  'TRX/USDT',
#  'TSHP/BTC',
#  'TSHP/KRW',
#  'TT/KRW',
#  'TUSD/BTC',
#  'TUSD/USDT',
#  'Tokamak Network/BTC',
#  'Tokamak Network/KRW',
#  'UNI/BTC',
#  'UPP/BTC',
#  'UPP/KRW',
#  'VAL/BTC',
#  'VET/BTC',
#  'VET/KRW',
#  'VITE/BTC',
#  'WAVES/BTC',
#  'WAVES/KRW',
#  'WAXP/BTC',
#  'WAXP/KRW',
#  'XEM/BTC',
#  'XEM/KRW',
#  'XLM/BTC',
#  'XLM/KRW',
#  'XRP/BTC',
#  'XRP/KRW',
#  'XRP/USDT',
#  'XTZ/BTC',
#  'XTZ/KRW',
#  'ZIL/BTC',
#  'ZIL/KRW',
#  'ZRX/BTC',
#  'ZRX/KRW',
#  'ZRX/USDT']

# %%
dt=['20160101', '20170101', '20180101', '20190101', '20200101','0210101', '20220101']

# %%
dt=['20210101']

# %%
print(dt)
# Out:
# ['20210101']

# %%
for coin in binance_coin_list:
    df = ohlcv(dt, coin, '1m')
    print(df)
    df.to_csv("temp.csv", header=True, index=True)
    break
# Out:
#                        Open    High     Low   Close    Volume
# Time
# 2021-01-01 09:00:00  2.5906  2.5949  2.5905  2.5941   3071.86
# 2021-01-01 09:01:00  2.5948  2.5990  2.5941  2.5986  15910.10
# 2021-01-01 09:02:00  2.5989  2.5993  2.5962  2.5974   6679.56
# 2021-01-01 09:03:00  2.5979  2.5996  2.5970  2.5976   2103.31
# 2021-01-01 09:04:00  2.5981  2.5991  2.5975  2.5978    503.34
# ...                     ...     ...     ...     ...       ...
# 2021-01-02 08:55:00  2.6241  2.6272  2.6240  2.6270   1326.48
# 2021-01-02 08:56:00  2.6274  2.6274  2.6274  2.6274     69.70
# 2021-01-02 08:57:00  2.6274  2.6321  2.6272  2.6321  52736.25
# 2021-01-02 08:58:00  2.6321  2.6333  2.6290  2.6301  14755.92
# 2021-01-02 08:59:00  2.6310  2.6400  2.6310  2.6378  30047.96
#
# [1440 rows x 5 columns]

# %%
print(df)
df.to_csv(filename)
# Out:
#                          Open      High       Low     Close   Volume
# Time
# 2019-05-30 09:00:00  0.031107  0.031117  0.031097  0.031110   70.714
# 2019-05-30 09:01:00  0.031111  0.031112  0.031083  0.031101  119.827
# 2019-05-30 09:02:00  0.031086  0.031101  0.031037  0.031037  272.337
# 2019-05-30 09:03:00  0.031038  0.031056  0.031030  0.031043  142.499
# 2019-05-30 09:04:00  0.031045  0.031066  0.031027  0.031065  126.115
# ...                       ...       ...       ...       ...      ...
# 2021-05-30 15:57:00  0.067880  0.067899  0.067806  0.067883  112.808
# 2021-05-30 15:58:00  0.067882  0.067923  0.067873  0.067923   65.316
# 2021-05-30 15:59:00  0.067920  0.067920  0.067789  0.067789  207.871
# 2021-05-30 16:00:00  0.067783  0.067817  0.067749  0.067768  102.765
# 2021-05-30 16:01:00  0.067790  0.067895  0.067786  0.067849  103.700
#
# [2284 rows x 5 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7a8151f6ab21> in <module>
#       1 print(df)
# ----> 2 df.to_csv(filename)
#
# NameError: name 'filename' is not defined

# %%
binance = ccxt.gopax()

def min_ohlcv(dt, pair, limit):
    # UTC native object
    since = calendar.timegm(dt.utctimetuple())*1000
    ohlcv1 = binance.fetch_ohlcv(symbol=pair, timeframe='1m', since=since, limit=limit)
    ohlcv2 = binance.fetch_ohlcv(symbol=pair, timeframe='1m', since=since, limit=limit)
    ohlcv = ohlcv1 + ohlcv2
    return ohlcv

def ohlcv(dt, pair, period='1d'):
    ohlcv = []
    limit = 1000
    if period == '1m':
        limit = 720
    elif period == '1d':
        limit = 365
    elif period == '1h':
        limit = 24
    elif period == '5m':
        limit = 288
    for i in dt:
        start_dt = datetime.strptime(i, "%Y%m%d")
        since = calendar.timegm(start_dt.utctimetuple())*1000
        if period == '1m':
            ohlcv.extend(min_ohlcv(start_dt, pair, limit))
        else:
            ohlcv.extend(binance.fetch_ohlcv(symbol=pair, timeframe=period, since=since, limit=limit))
    df = pd.DataFrame(ohlcv, columns = ['Time', 'Open', 'High', 'Low', 'Close', 'Volume'])
    df['Time'] = [datetime.fromtimestamp(float(time)/1000) for time in df['Time']]
    df['Open'] = df['Open'].astype(np.float64)
    df['High'] = df['High'].astype(np.float64)
    df['Low'] = df['Low'].astype(np.float64)
    df['Close'] = df['Close'].astype(np.float64)
    df['Volume'] = df['Volume'].astype(np.float64)
    df.set_index('Time', inplace=True)
    return df




dt = ['2021529', '20210530']
df = ohlcv(dt, 'ETH/KRW', '5m')

# %%
print(df)
# Out:
#                           Open       High        Low      Close      Volume
# Time
# 2021-05-29 09:00:00  2946000.0  2961000.0  2925000.0  2932000.0  157.048588
# 2021-05-29 09:05:00  2934000.0  2955000.0  2928000.0  2948000.0   21.188513
# 2021-05-29 09:10:00  2948000.0  2977000.0  2948000.0  2974000.0    9.146444
# 2021-05-29 09:15:00  2973000.0  3002000.0  2971000.0  2997000.0   48.980087
# 2021-05-29 09:20:00  2993000.0  2996000.0  2988000.0  2991000.0   12.207341
# ...                        ...        ...        ...        ...         ...
# 2021-05-30 15:40:00  2910000.0  2921000.0  2908000.0  2917000.0   16.051141
# 2021-05-30 15:45:00  2916000.0  2929000.0  2910000.0  2926000.0   20.410073
# 2021-05-30 15:50:00  2930000.0  2942000.0  2930000.0  2941000.0   22.297383
# 2021-05-30 15:55:00  2942000.0  2945000.0  2936000.0  2936000.0   11.055978
# 2021-05-30 16:00:00  2936000.0  2955000.0  2936000.0  2955000.0   13.646019
#
# [373 rows x 5 columns]

# %%
import ccxt
import pandas as pd

exch = 'binance' # initial exchange
t_frame = '1d' # 1-day timeframe, usually from 1-minute to 1-week depending on the exchange
symbol = 'ADA/BTC' # initial symbol
exchange_list = ['binance','bitfinex','bytetrade','ftx','kraken','poloniex','upbit','acx','bequant','bigone','bitforex','bitkk','bitz','btcalpha','coinex','crex24','digifinex','gateio','hitbtc2','huobipro','huobiru','kucoin','lbank','okex','okex3','stex','upbit','whitebit','zb']
 
# Get our Exchange
try:
    exchange = getattr (ccxt, exch) ()
except AttributeError:
    print('-'*36,' ERROR ','-'*35)
    print('Exchange "{}" not found. Please check the exchange is supported.'.format(exch))
    print('-'*80)
    quit()
 
# Check if fetching of OHLC Data is supported
if exchange.has["fetchOHLCV"] != True:
    print('-'*36,' ERROR ','-'*35)
    print('{} does not support fetching OHLC data. Please use another  exchange'.format(exch))
    print('-'*80)
    quit()
 
# Check requested timeframe is available. If not return a helpful error.
if (not hasattr(exchange, 'timeframes')) or (t_frame not in exchange.timeframes):
    print('-'*36,' ERROR ','-'*35)
    print('The requested timeframe ({}) is not available from {}\n'.format(t_frame,exch))
    print('Available timeframes are:')
    for key in exchange.timeframes.keys():
        print('  - ' + key)
    print('-'*80)
    quit()
 
# Check if the symbol is available on the Exchange
exchange.load_markets()
if symbol not in exchange.symbols:
    print('-'*36,' ERROR ','-'*35)
    print('The requested symbol ({}) is not available from {}\n'.format(symbol,exch))
    print('Available symbols are:')
    for key in exchange.symbols:
        print('  - ' + key)
    print('-'*80)
    quit()
 
 
# Get data
data = exchange.fetch_ohlcv(symbol, t_frame)
header = ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(data, columns=header).set_index('Timestamp')
df['symbol'] = symbol
syms = [symbol]
filename = '{}.csv'.format(t_frame)

for exch in exchange_list:
    try:
        exchange = getattr (ccxt, exch) ()
    except AttributeError:
        print('-'*36,' ERROR ','-'*35)
        print('Exchange "{}" not found. Please check the exchange is supported.'.format(exch))
        print('-'*80)
        quit()
    if exchange.has["fetchOHLCV"] != True:
        print('-'*36,' ERROR ','-'*35)
        print('{} does not support fetching OHLC data. Please use another exchange'.format(exch))
        print('-'*80)
        quit()
    if (not hasattr(exchange, 'timeframes')) or (t_frame not in exchange.timeframes):
        print('-'*36,' ERROR ','-'*35)
        print('The requested timeframe ({}) is not available from {}\n'.format(t_frame,exch))
        print('Available timeframes are:')
        for key in exchange.timeframes.keys():
            print('  - ' + key)
        print('-'*80)
        quit()
    exchange.load_markets()
    for coin in exchange.symbols:
        if coin in syms or coin[-3:] != 'BTC':
            continue
        else:
            try:
                data = exchange.fetch_ohlcv(coin, t_frame)
            except:
                continue
            data_df = pd.DataFrame(data, columns=header).set_index('Timestamp')
            data_df['symbol'] = coin
            df = df.append(data_df)
            syms.append(coin)
df.index = df.index/1000 #Timestamp is 1000 times bigger than it should be in this case
df['Date'] = pd.to_datetime(df.index,unit='s')
df.to_csv(filename)
# Out:
# ------------------------------------  ERROR  -----------------------------------
# Exchange "acx" not found. Please check the exchange is supported.
# --------------------------------------------------------------------------------
