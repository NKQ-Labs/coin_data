# %%
import os
import pandas as pd
import datetime as dt

# %%
#os.mkdir('tempDir')
os.path.isdir( os.path.join(os.getcwd(), '/tempDir'))
# Out:
# False

# %% [markdown]
# GoPax folder

# %%
gopax_base_path=os.path.join(os.getcwd(), 'GoPax_5min')

# %%
print(gopax_base_path)

print(os.getcwd())
# Out:
# C:\Users\Sodam Im\coin_data\GoPax_5min
# C:\Users\Sodam Im\coin_data

# %%
os.path.isdir(gopax_base_path)
# Out:
# True

# %%
os.path.join(os.getcwd(), 'new_folder')
# Out:
# 'C:\\Users\\Sodam Im\\coin_data\\new_folder'

# %%
dirName = 'tempDir2/temp2/temp'

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2020,1,1), end = dt.datetime.now(), freq='M'))

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-31 00:00:00, 2020-02-29 00:00:00, 2020-03-31 00:00:00, 2020-04-30 00:00:00, 2020-05-31 00:00:00, 2020-06-30 00:00:00, 2020-07-31 00:00:00, 2020-08-31 00:00:00, 2020-09-30 00:00:00, 2020-10-31 00:00:00, 2020-11-30 00:00:00, 2020-12-31 00:00:00, 2021-01-31 00:00:00, 2021-02-28 00:00:00, 2021-03-31 00:00:00, 2021-04-30 00:00:00]

# %%
month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y-%m'))

# %%
month_list=month_list.tolist()

# %%
month_list
# Out:
# ['2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2021-01',
#  '2021-02',
#  '2021-03',
#  '2021-04']

# %%
pd.Series()
# Out:
# <ipython-input-12-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %%
month_list=month_list.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-949532d1abda> in <module>
# ----> 1 month_list=month_list.tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
for time in month_list:
    print(os.path.join(gopax_base_path,time) )
    if os.path.isdir ( os.path.join(gopax_base_path,time) ) is False:
        os.mkdir(os.path.join(gopax_base_path,time) )
# Out:
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-01
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-02
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-03
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-04
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-05
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-06
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-07
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-08
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-09
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-10
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-11
# C:\Users\Sodam Im\coin_data\GoPax_5min\2020-12
# C:\Users\Sodam Im\coin_data\GoPax_5min\2021-01
# C:\Users\Sodam Im\coin_data\GoPax_5min\2021-02
# C:\Users\Sodam Im\coin_data\GoPax_5min\2021-03
# C:\Users\Sodam Im\coin_data\GoPax_5min\2021-04

# %%
binance_base_path=os.path.join(os.getcwd(), 'binance_1min')
upbit_base_path=os.path.join(os.getcwd(), 'upbit_1min')

df = pd.DataFrame(index=pd.date_range(start = dt.datetime(2015,1,1), end = dt.datetime.now(), freq='M'))

month_list=df.index.to_series().apply(lambda x: dt.datetime.strftime(x, '%Y-%m'))

# %%
month_list=month_list.to_list()
print(month_list)
# Out:
# ['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04']

# %%
for time in month_list:
    print(os.path.join(upbit_base_path,time) )
    if os.path.isdir ( os.path.join(binance_base_path,time) ) is False:
        
        os.mkdir(os.path.join(upbit_base_path,time) )







for time in month_list:
    print(os.path.join(binance_base_path,time) )
    if os.path.isdir ( os.path.join(binance_base_path,time) ) is False:
        os.mkdir(      os.path.join(binance_base_path,time) )
# Out:
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-01
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-02
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-03
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-04
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-05
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-06
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-07
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-08
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-09
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-10
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-11
# C:\Users\Sodam Im\coin_data\upbit_1min\2015-12
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-01
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-02
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-03
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-04
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-05
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-06
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-07
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-08
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-09
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-10
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-11
# C:\Users\Sodam Im\coin_data\upbit_1min\2016-12
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-01
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-02
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-03
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-04
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-05
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-06
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-07
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-08
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-09
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-10
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-11
# C:\Users\Sodam Im\coin_data\upbit_1min\2017-12
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-01
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-02
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-03
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-04
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-05
# C:\Users\Sodam Im\coin_data\upbit_1min\2018-06
